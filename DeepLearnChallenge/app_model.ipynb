# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN','NAME'])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df.APPLICATION_TYPE.value_counts()
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
app_type_counts = application_df.APPLICATION_TYPE.value_counts()

application_types_to_replace = app_type_counts[app_type_counts < 500].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df.CLASSIFICATION.value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
values_greater_than_one = application_df.CLASSIFICATION.value_counts()
values_greater_than_one = values_greater_than_one[values_greater_than_one > 1]
values_greater_than_one
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classification_counts = application_df.CLASSIFICATION.value_counts()
classifications_to_replace = classification_counts[classification_counts < 1000].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
df_dummies = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
X = df_dummies.drop(columns='IS_SUCCESSFUL')
y = df_dummies['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

input_features = X.shape[1]

# First hidden layer
nn.add(tf.keras.layers.Dense(units=10, activation='relu',input_dim=input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=10, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 10)                440
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# ...
# Total params: 561 (2.19 KB)
# Trainable params: 561 (2.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# Train the model
train_model = nn.fit(X_train_scaled,y_train,epochs=250)
# Out:
# Epoch 1/250
# 804/804 [==============================] - 2s 1ms/step - loss: 0.6016 - accuracy: 0.7046
# Epoch 2/250
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5621 - accuracy: 0.7278
# Epoch 3/250
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5573 - accuracy: 0.7287
# Epoch 4/250
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5551 - accuracy: 0.7307
# Epoch 5/250
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5540 - accuracy: 0.7313
# Epoch 6/250
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5532 - accuracy: 0.7314
# Epoch 7/250
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5522 - accuracy: 0.7314
# Epoch 8/250
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5515 - accuracy: 0.7314
# Epoch 9/250
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5507 - accuracy: 0.7328
# Epoch 10/250
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5553 - accuracy: 0.7245 - 435ms/epoch - 2ms/step
# Loss: 0.5552834868431091, Accuracy: 0.7245481014251709

# %%
# SECOND ATTEMPT - INCREASING THE NUMBER OF UNITS TO 50

# First hidden layer
nn.add(tf.keras.layers.Dense(units=50, activation='relu',input_dim=input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=50, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 10)                440
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
#  dense_3 (Dense)             (None, 50)                100
#
#  dense_4 (Dense)             (None, 50)                2550
#
#  dense_5 (Dense)             (None, 1)                 51
#
# ...
# Total params: 3262 (12.74 KB)
# Trainable params: 3262 (12.74 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
nn.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

train_model = nn.fit(X_train_scaled,y_train,epochs=250)
# Out:
# Epoch 1/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5664 - accuracy: 0.7262
# Epoch 2/250
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5463 - accuracy: 0.7379
# Epoch 3/250
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5454 - accuracy: 0.7365
# Epoch 4/250
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5440 - accuracy: 0.7367
# Epoch 5/250
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5440 - accuracy: 0.7371
# Epoch 6/250
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5437 - accuracy: 0.7362
# Epoch 7/250
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5437 - accuracy: 0.7376
# Epoch 8/250
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5431 - accuracy: 0.7386
# Epoch 9/250
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7376
# Epoch 10/250
# ...

# %%
model_loss2, model_accuracy2 = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss2}, Accuracy: {model_accuracy2}")
# Out:
# 268/268 - 0s - loss: 0.5547 - accuracy: 0.7247 - 346ms/epoch - 1ms/step
# Loss: 0.5547472238540649, Accuracy: 0.7246647477149963

# %%
# THIRD ATTEMPT - INCREASING THE NUMBER OF UNITS TO 75, ADDING A THIRD LAYER, AND INCREASING EPOCHS TO 400

# First hidden layer
nn.add(tf.keras.layers.Dense(units=75, activation='relu',input_dim=input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=75, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=75, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 10)                440
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
#  dense_3 (Dense)             (None, 50)                100
#
#  dense_4 (Dense)             (None, 50)                2550
#
#  dense_5 (Dense)             (None, 1)                 51
#
#  dense_6 (Dense)             (None, 75)                150
#
#  dense_7 (Dense)             (None, 75)                5700
#
#  dense_8 (Dense)             (None, 75)                5700
#
#  dense_9 (Dense)             (None, 1)                 76
#
# ...
# Total params: 14888 (58.16 KB)
# Trainable params: 14888 (58.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
nn.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

train_model = nn.fit(X_train_scaled,y_train,epochs=400)
# Out:
# Epoch 1/400
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5549 - accuracy: 0.7315
# Epoch 2/400
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5449 - accuracy: 0.7363
# Epoch 3/400
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5445 - accuracy: 0.7365
# Epoch 4/400
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5435 - accuracy: 0.7372
# Epoch 5/400
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5428 - accuracy: 0.7375
# Epoch 6/400
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5430 - accuracy: 0.7371
# Epoch 7/400
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5427 - accuracy: 0.7376
# Epoch 8/400
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7363
# Epoch 9/400
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5416 - accuracy: 0.7378
# Epoch 10/400
# ...

# %%
model_loss3, model_accuracy3 = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss3}, Accuracy: {model_accuracy3}")
# Out:
# 268/268 - 0s - loss: 0.5546 - accuracy: 0.7263 - 395ms/epoch - 1ms/step
# Loss: 0.5546301603317261, Accuracy: 0.7262973785400391

# %%
! pip install h5py
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
# Export our model to HDF5 file
nn.save('application_model.h5')
# Out:
# c:\Python311\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
